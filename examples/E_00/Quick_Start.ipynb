# %% [markdown]
# # MFW 6 + flopy + matplotlib
#
# **Autor: Luis M. de la Cruz**
#
# <font color=#FF0000>**Última actualización: Sun Jan 14 16:51:05 2024**</font>

# %% [markdown]
# ## Paso 1. Importamos las bibliotecas
# Importamos todas las bibliotecas `os` (para acceso al sistema operativo) y `flopy`.

# %%
import os
import flopy

# %% [markdown]
# ## Paso 2. Definimos la ruta de MODFLOW
# Definimos la ruta donde se encuentra el ejecutable de MODFLOW 6 y el nombre de la simulación.

# %%
ws = os.getcwd() # Ruta de donde estamos actualmente

# WINDOWS (descomente la siguiente línea)
#mf6_exe = 'C:\\Users\\luiggi\\Downloads\\mf6.4.2\\mf6.4.2_win64\\bin\\mf6.exe'

# MAC (descomente la siguiente línea)
mf6_exe = '/Users/luiggi/GitSites/mf6.4.4_mac/bin/mf6'

# LINUX (MACTI) (descomente la siguiente línea)
#mf6_exe = '/home/jovyan/MODFLOW/mf6.4.2_linux/bin/mf6'

# Definimos el nombre de la simulación
name = 'quick_start'

print(' Ruta hacia el ejecutable de MODFLOW 6 : {} '.format(mf6_exe))
print(' Nombre de esta simulación: {}'.format(name))
# Out:
#  Ruta hacia el ejecutable de MODFLOW 6 : /Users/luiggi/GitSites/mf6.4.4_mac/bin/mf6
#  Nombre de esta simulación: quick_start

# %% [markdown]
# ## Paso 3. Objeto para la simulación
# Creamos un objeto de tipo `MFSimulation`

# %%
sim  = flopy.mf6.MFSimulation(sim_name=name, sim_ws=ws, exe_name=mf6_exe)

# %%
print(type(sim),'\n')
print(sim)
# Out:
# <class 'flopy.mf6.modflow.mfsimulation.MFSimulation'>
#
# sim_name = quick_start
# sim_path = /Users/luiggi/GitSites/mf6py/E_00
# exe_name = /Users/luiggi/GitSites/mf6.4.4_mac/bin/mf6
#
# ###################
# Package mfsim.nam
# ###################
#
# package_name = mfsim.nam
# filename = mfsim.nam
# package_type = nam
# model_or_simulation_package = simulation
# simulation_name = quick_start

# %% [markdown]
# ## Paso 4. Objeto para el tiempo
# Creamos un objeto de tipo `ModflowTDis` para la discretización en el tiempo

# %%
tdis = flopy.mf6.ModflowTdis(sim)

# %%
print(type(tdis),'\n')
print(tdis)
# Out:
# <class 'flopy.mf6.modflow.mftdis.ModflowTdis'>
#
# package_name = quick_start.tdis
# filename = quick_start.tdis
# package_type = tdis
# model_or_simulation_package = simulation
# simulation_name = quick_start
#
# Block dimensions
# --------------------
# nper
# {internal}
# (1)
#
#
# Block perioddata
# --------------------
# perioddata
# {internal}
# ([(1., 1, 1.)])

# %%
sim.write_simulation()
# Out:
# writing simulation...
#   writing simulation name file...
#   writing simulation tdis package...

# %% [markdown]
# ## Paso 5. Objeto para la solución.
#
# Creamos un objeto de tipo `ModflowIms` para la solución iterativa

# %%
ims  = flopy.mf6.ModflowIms(sim)

# %%
print(type(ims), '\n')
print(ims)
# Out:
# <class 'flopy.mf6.modflow.mfims.ModflowIms'>
#
# package_name = ims_-1
# filename = quick_start.ims
# package_type = ims
# model_or_simulation_package = simulation
# simulation_name = quick_start

# %%
sim.write_simulation()
# Out:
# writing simulation...
#   writing simulation name file...
#   writing simulation tdis package...
#   writing solution package ims_-1...

# %% [markdown]
# ## Paso 6. Objeto para el modelo de flujo
# Creamos un modelo de flujo usando `ModflowGwf`

# %%
gwf  = flopy.mf6.ModflowGwf(sim, modelname=name, save_flows=True)

# %%
print(type(gwf), '\n')
print(gwf)
# Out:
# <class 'flopy.mf6.modflow.mfgwf.ModflowGwf'>
#
# name = quick_start
# model_type = gwf6
# version = mf6
# model_relative_path = .

# %%
sim.write_simulation()
# Out:
# writing simulation...
#   writing simulation name file...
#   writing simulation tdis package...
#   writing solution package ims_-1...
#   writing model quick_start...
#     writing model name file...

# %% [markdown]
# ## Paso 7. Objeto para la malla
#
# Creamos un objeto para la discretización espacial
# En Modflow 6 existen tres maneras:
# - DIS (ModflowGwfdis) - Structured discretization
# - DISV (ModflowGwfdisv) - Discretization with vertices
# - DISU (ModflowGwfdisu) - Unstructured discretization

# %%
nrow = 20
ncol = 20
dis  = flopy.mf6.ModflowGwfdis(gwf, nrow=nrow, ncol=ncol)

# %%
print(type(dis), '\n')
print(dis)
# Out:
# <class 'flopy.mf6.modflow.mfgwfdis.ModflowGwfdis'>
#
# package_name = dis
# filename = quick_start.dis
# package_type = dis
# model_or_simulation_package = model
# model_name = quick_start
#
# Block dimensions
# --------------------
# nlay
# {internal}
# (1)
#
# nrow
# {internal}
# (20)
#
# ncol
# {internal}
# (20)
#
#
# Block griddata
# --------------------
# delr
# {constant 1.0}
#
# delc
# {constant 1.0}
#
# top
# {constant 1.0}
#
# botm
# {constant 0.0}

# %%
sim.write_simulation()
# Out:
# writing simulation...
#   writing simulation name file...
#   writing simulation tdis package...
#   writing solution package ims_-1...
#   writing model quick_start...
#     writing model name file...
#     writing package dis...

# %% [markdown]
# ## Paso 8. Condiciones iniciales
#
# Creamos un objeto de tipo `ModflowGwfic` para las condiciones iniciales.

# %%
ic   = flopy.mf6.ModflowGwfic(gwf)

# %%
sim.write_simulation()
# Out:
# writing simulation...
#   writing simulation name file...
#   writing simulation tdis package...
#   writing solution package ims_-1...
#   writing model quick_start...
#     writing model name file...
#     writing package dis...
#     writing package ic...

# %% [markdown]
# ## Paso 9. Propiedades de los nodos
#
# Creamos un objeto de tipo `ModflowGwfnpf` para definir propiedades en los nodos y otro de tipo `ModflowGwfchd` para definir la carga constante

# %%
npf  = flopy.mf6.ModflowGwfnpf(gwf, save_specific_discharge=True)

# %%
print(type(npf),'\n')
print(npf)
# Out:
# <class 'flopy.mf6.modflow.mfgwfnpf.ModflowGwfnpf'>
#
# package_name = npf
# filename = quick_start.npf
# package_type = npf
# model_or_simulation_package = model
# model_name = quick_start
#
# Block options
# --------------------
# save_specific_discharge
# {internal}
# (True)
#
#
# Block griddata
# --------------------
# icelltype
# {constant 0}
#
# k
# {constant 1.0}

# %%
sim.write_simulation()
# Out:
# writing simulation...
#   writing simulation name file...
#   writing simulation tdis package...
#   writing solution package ims_-1...
#   writing model quick_start...
#     writing model name file...
#     writing package dis...
#     writing package ic...
#     writing package npf...

# %%
xc = nrow-1
yc = ncol-1
chd  = flopy.mf6.ModflowGwfchd(gwf, stress_period_data=[[(0, 0, 0), 10.],
                                                        [(0, int(xc/2), int(yc/2)), 2.5],
                                                       [(0, xc, yc), 0.]])

# %%
print(type(chd),'\n')
print(chd)
# Out:
# <class 'flopy.mf6.modflow.mfgwfchd.ModflowGwfchd'>
#
# package_name = chd_0
# filename = quick_start.chd
# package_type = chd
# model_or_simulation_package = model
# model_name = quick_start
#
# Block period
# --------------------
# stress_period_data
# {internal}
# ([((0, 0, 0), 10. ) ((0, 9, 9),  2.5) ((0, 19, 19),  0. )])

# %%
sim.write_simulation()
# Out:
# writing simulation...
#   writing simulation name file...
#   writing simulation tdis package...
#   writing solution package ims_-1...
#   writing model quick_start...
#     writing model name file...
#     writing package dis...
#     writing package ic...
#     writing package npf...
#     writing package chd_0...
# INFORMATION: maxbound in ('gwf6', 'chd', 'dimensions') changed to 3 based on size of stress_period_data

# %% [markdown]
# ## Paso 10. Objeto para la salida.
# Creamos un objeto de tipo `ModflowGwfoc` para la salida de la simulación

# %%
budget_file = name + '.bud'
head_file = name + '.hds'

oc = flopy.mf6.ModflowGwfoc(gwf,
                            budget_filerecord=budget_file,
                            head_filerecord=head_file,
                            saverecord=[('HEAD', 'ALL'), ('BUDGET', 'ALL')])

# %%
print(type(oc),'\n')
print(oc)
# Out:
# <class 'flopy.mf6.modflow.mfgwfoc.ModflowGwfoc'>
#
# package_name = oc
# filename = quick_start.oc
# package_type = oc
# model_or_simulation_package = model
# model_name = quick_start
#
# Block options
# --------------------
# budget_filerecord
# {internal}
# ([('quick_start.bud',)])
#
# head_filerecord
# {internal}
# ([('quick_start.hds',)])
#
#
# Block period
# --------------------
# saverecord
# {internal}
# ([('HEAD', 'ALL', None) ('BUDGET', 'ALL', None)])
#
# printrecord
# None

# %% [markdown]
# ## Paso 11. Archivos de entrada.
# Escribimos los datos de entrada para la simulación

# %%
sim.write_simulation()
# Out:
# writing simulation...
#   writing simulation name file...
#   writing simulation tdis package...
#   writing solution package ims_-1...
#   writing model quick_start...
#     writing model name file...
#     writing package dis...
#     writing package ic...
#     writing package npf...
#     writing package chd_0...
#     writing package oc...

# %% [markdown]
# ## Paso 12. Ejecución
# Ejecutamos la simulación

# %%
sim.run_simulation()
# Out:
# FloPy is using the following executable to run the model: ../../mf6.4.4_mac/bin/mf6
#                                    MODFLOW 6
#                 U.S. GEOLOGICAL SURVEY MODULAR HYDROLOGIC MODEL
#                             VERSION 6.4.4 02/13/2024
#
#    MODFLOW 6 compiled Feb 13 2024 17:58:17 with Intel(R) Fortran Intel(R) 64
#    Compiler Classic for applications running on Intel(R) 64, Version 2021.7.0
#                              Build 20220726_000000
#
# This software has been approved for release by the U.S. Geological
# Survey (USGS). Although the software has been subjected to rigorous
# review, the USGS reserves the right to update the software as needed
# pursuant to further analysis and review. No warranty, expressed or
# implied, is made by the USGS or the U.S. Government as to the
# functionality of the software and related material nor shall the
# fact of release constitute any such warranty. Furthermore, the
# software is released on condition that neither the USGS nor the U.S.
# Government shall be held liable for any damages resulting from its
# authorized or unauthorized use. Also refer to the USGS Water
# Resources Software User Rights Notice for complete use, copyright,
# and distribution information.
#
#
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2024/04/11 17:15:27
#
#  Writing simulation list file: mfsim.lst
#  Using Simulation name file: mfsim.nam
#
#     Solving:  Stress period:     1    Time step:     1
#
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2024/04/11 17:15:27
#  Elapsed run time:  0.036 Seconds
#
#  Normal termination of simulation.
# (True, [])

# %% [markdown]
# ## Paso 13. Recuperamos la salida.
# Realizamos la visualización

# %%
head = flopy.utils.HeadFile(os.path.join(ws, head_file)).get_data()
bud  = flopy.utils.CellBudgetFile(os.path.join(ws, budget_file),
                                  precision='double')

spdis = bud.get_data(text='DATA-SPDIS')[0]

# %%
# Out:
# <property object at 0x10dc05530>

# %%
print(head)
# Out:
# [[[10.          8.23556707  7.16888445  6.43103434  5.87438021
#     5.43105999  5.06601164  4.75948894  4.49950911  4.27825322
#     4.09020414  3.93110892  3.79745349  3.68627757  3.59510013
#     3.52188345  3.46502724  3.42334694  3.39604153  3.3825462 ]
#   [ 8.23556707  7.53779864  6.8400461   6.24981485  5.7610425
#     5.35272685  5.00745351  4.71294668  4.4607838   4.24504242
#     4.06124857  3.90566896  3.77498693  3.66628976  3.57712368
#     3.50549676  3.44983171  3.40896298  3.38213059  3.36891451]
#   [ 7.16888445  6.8400461   6.40365264  5.9672562   5.56724183
#  (113, 113, 0.,  0.08126963, -0.1107166 , 0.)
#  (114, 114, 0.,  0.06767002, -0.0965344 , 0.)
#  (115, 115, 0.,  0.05628632, -0.08613993, 0.)
#  (116, 116, 0.,  0.04589538, -0.07887173, 0.)
#  (117, 117, 0.,  0.03581529, -0.07399315, 0.)
#  (118, 118, 0.,  0.02572159, -0.07087234, 0.)
#  (119, 119, 0.,  0.01549869, -0.06905027, 0.)
#  (120, 120, 0.,  0.01035587, -0.06819875, 0.)
#  (121, 121, 0.,  0.05855813, -0.33578553, 0.)
#  (122, 122, 0.,  0.08391207, -0.31989008, 0.)
#  (123, 123, 0.,  0.12880354, -0.2936529 , 0.)
#  (124, 124, 0.,  0.1619656 , -0.26391572, 0.)
#  (125, 125, 0.,  0.18412268, -0.23624779, 0.)
#  (126, 126, 0.,  0.19689958, -0.21447403, 0.)
#  (127, 127, 0.,  0.20114368, -0.20114368, 0.)
#  (128, 128, 0.,  0.19551361, -0.19768414, 0.)
#  (129, 129, 0.,  0.17580338, -0.20267491, 0.)
#  (130, 130, 0.,  0.13890303, -0.20548819, 0.)
#  (131, 131, 0.,  0.10067183, -0.17807952, 0.)
#  (132, 132, 0.,  0.07670449, -0.14745466, 0.)
#  (133, 133, 0.,  0.06310489, -0.12328088, 0.)
#  (134, 134, 0.,  0.05429194, -0.1063144 , 0.)
#  (135, 135, 0.,  0.04696819, -0.0950042 , 0.)
#  (136, 136, 0.,  0.03965746, -0.08767702, 0.)
#  (137, 137, 0.,  0.03181123, -0.08308919, 0.)
#  (138, 138, 0.,  0.02330654, -0.0803289 , 0.)
#  (139, 139, 0.,  0.01422618, -0.07881143, 0.)
#  (140, 140, 0.,  0.0095607 , -0.07814681, 0.)
#  (141, 141, 0.,  0.04654226, -0.28325127, 0.)
#  (142, 142, 0.,  0.06770681, -0.27333486, 0.)
#  (143, 143, 0.,  0.10670173, -0.25628593, 0.)
#  (144, 144, 0.,  0.13877368, -0.23606671, 0.)
#  (145, 145, 0.,  0.16408762, -0.21665848, 0.)
#  (146, 146, 0.,  0.18360712, -0.20178539, 0.)
#  (147, 147, 0.,  0.19768414, -0.19551361, 0.)
#  (148, 148, 0.,  0.20331662, -0.20331662, 0.)
#  (149, 149, 0.,  0.18829726, -0.23176725, 0.)
#  (150, 150, 0.,  0.1272748 , -0.2743057 , 0.)
#  (151, 151, 0.,  0.06452783, -0.21023862, 0.)
#  (152, 152, 0.,  0.04412191, -0.15966628, 0.)
#  (153, 153, 0.,  0.04012938, -0.12866784, 0.)
#  (154, 154, 0.,  0.03939334, -0.11047009, 0.)
#  (155, 155, 0.,  0.03764894, -0.09985555, 0.)
#  (156, 156, 0.,  0.03398037, -0.09374384, 0.)
#  (157, 157, 0.,  0.02846717, -0.09034801, 0.)
#  (158, 158, 0.,  0.02144384, -0.0885719 , 0.)
#  (159, 159, 0.,  0.0133166 , -0.08773441, 0.)
#  (160, 160, 0.,  0.00902662, -0.08742401, 0.)
#  (161, 161, 0.,  0.03872531, -0.24061786, 0.)
#  (162, 162, 0.,  0.05694673, -0.23395213, 0.)
#  (163, 163, 0.,  0.09153539, -0.22209786, 0.)
#  (164, 164, 0.,  0.12233815, -0.20739008, 0.)
#  (165, 165, 0.,  0.14984136, -0.19251358, 0.)
#  (166, 166, 0.,  0.17575471, -0.18049321, 0.)
#  (167, 167, 0.,  0.20267491, -0.17580338, 0.)
#  (168, 168, 0.,  0.23176725, -0.18829726, 0.)
#  (169, 169, 0.,  0.24679246, -0.24679246, 0.)
#  (170, 170, 0.,  0.11737441, -0.44970259, 0.)
#  (171, 171, 0., -0.0139676 , -0.22890558, 0.)
#  (172, 172, 0., -0.0048663 , -0.15227223, 0.)
#  (173, 173, 0.,  0.01390871, -0.12124688, 0.)
#  (174, 174, 0.,  0.02547965, -0.1070506 , 0.)
#  (175, 175, 0.,  0.03024194, -0.10021297, 0.)
#  (176, 176, 0.,  0.03014992, -0.09709142, 0.)
#  (177, 177, 0.,  0.02663929, -0.09596871, 0.)
#  (178, 178, 0.,  0.02069294, -0.09587153, 0.)
#  (179, 179, 0.,  0.01307829, -0.09615278, 0.)
#  (180, 180, 0.,  0.00893989, -0.09640084, 0.)
#  (181, 181, 0.,  0.03321081, -0.20465248, 0.)
#  (182, 182, 0.,  0.04918681, -0.19976762, 0.)
#  (183, 183, 0.,  0.08013968, -0.19075849, 0.)
#  (184, 184, 0.,  0.1091894 , -0.1788747 , 0.)
#  (185, 185, 0.,  0.13719075, -0.16550244, 0.)
#  (186, 186, 0.,  0.16689692, -0.15187019, 0.)
#  (187, 187, 0.,  0.20548819, -0.13890303, 0.)
#  (188, 188, 0.,  0.2743057 , -0.1272748 , 0.)
#  (189, 189, 0.,  0.44970259, -0.11737441, 0.)
#  (190, 190, 0.,  0.10938792, -0.10938792, 0.)
#  (191, 191, 0., -0.23290254, -0.1033717 , 0.)
#  (192, 192, 0., -0.0635368 , -0.09927506, 0.)
#  (193, 193, 0., -0.00509225, -0.0969806 , 0.)
#  (194, 194, 0.,  0.01835942, -0.09626621, 0.)
#  (195, 195, 0.,  0.02768975, -0.0968686 , 0.)
#  (196, 196, 0.,  0.02973611, -0.09844645, 0.)
#  (197, 197, 0.,  0.02724728, -0.10057384, 0.)
#  (198, 198, 0.,  0.0216279 , -0.1027877 , 0.)
#  (199, 199, 0.,  0.01384591, -0.10460792, 0.)
#  (200, 200, 0.,  0.00952274, -0.10563361, 0.)
#  (201, 201, 0.,  0.02895557, -0.17357215, 0.)
#  (202, 202, 0.,  0.04305274, -0.16968673, 0.)
#  (203, 203, 0.,  0.07064248, -0.16227616, 0.)
#  (204, 204, 0.,  0.09708209, -0.15185547, 0.)
#  (205, 205, 0.,  0.12283685, -0.13875953, 0.)
#  (206, 206, 0.,  0.1491553 , -0.12256136, 0.)
#  (207, 207, 0.,  0.17807952, -0.10067183, 0.)
#  (208, 208, 0.,  0.21023862, -0.06452783, 0.)
#  (209, 209, 0.,  0.22890558,  0.0139676 , 0.)
#  (210, 210, 0.,  0.1033717 ,  0.23290254, 0.)
#  (211, 211, 0., -0.02408046,  0.02408046, 0.)
#  (212, 212, 0., -0.01125741, -0.04449797, 0.)
#  (213, 213, 0.,  0.01089986, -0.0711273 , 0.)
#  (214, 214, 0.,  0.02536766, -0.08417348, 0.)
#  (215, 215, 0.,  0.03242218, -0.09256711, 0.)
#  (216, 216, 0.,  0.03385516, -0.09926682, 0.)
#  (217, 217, 0.,  0.03098053, -0.10511964, 0.)
#  (218, 218, 0.,  0.02472703, -0.110114  , 0.)
#  (219, 219, 0.,  0.0159242 , -0.1138625 , 0.)
#  (220, 220, 0.,  0.01099126, -0.1158946 , 0.)
#  (221, 221, 0.,  0.02543996, -0.14637532, 0.)
#  (222, 222, 0.,  0.03789082, -0.14313082, 0.)
#  (223, 223, 0.,  0.06230842, -0.13679476, 0.)
#  (224, 224, 0.,  0.08567277, -0.12751246, 0.)
#  (225, 225, 0.,  0.10789664, -0.11514319, 0.)
#  (226, 226, 0.,  0.12880922, -0.09892054, 0.)
#  (227, 227, 0.,  0.14745466, -0.07670449, 0.)
#  (228, 228, 0.,  0.15966628, -0.04412191, 0.)
#  (229, 229, 0.,  0.15227223,  0.0048663 , 0.)
#  (230, 230, 0.,  0.09927506,  0.0635368 , 0.)
#  (231, 231, 0.,  0.04449797,  0.01125741, 0.)
#  (232, 232, 0.,  0.03167096, -0.03167096, 0.)
#  (233, 233, 0.,  0.03458327, -0.05886875, 0.)
#  (234, 234, 0.,  0.03979923, -0.07673394, 0.)
#  (235, 235, 0.,  0.04278309, -0.08996342, 0.)
#  (236, 236, 0.,  0.04228865, -0.10094003, 0.)
#  (237, 237, 0.,  0.03809446, -0.11053634, 0.)
#  (238, 238, 0.,  0.03037077, -0.11870009, 0.)
#  (239, 239, 0.,  0.01962651, -0.1248419 , 0.)
#  (240, 240, 0.,  0.01358693, -0.12819007, 0.)
#  (241, 241, 0.,  0.02246657, -0.12241567, 0.)
#  (242, 242, 0.,  0.03347218, -0.1196896 , 0.)
#  (243, 243, 0.,  0.05502411, -0.11428214, 0.)
#  (244, 244, 0.,  0.07543052, -0.10623461, 0.)
#  (245, 245, 0.,  0.09424494, -0.09537972, 0.)
#  (246, 246, 0.,  0.1107166 , -0.08126963, 0.)
#  (247, 247, 0.,  0.12328088, -0.06310489, 0.)
#  (248, 248, 0.,  0.12866784, -0.04012938, 0.)
#  (249, 249, 0.,  0.12124688, -0.01390871, 0.)
#  (250, 250, 0.,  0.0969806 ,  0.00509225, 0.)
#  (251, 251, 0.,  0.0711273 , -0.01089986, 0.)
#  (252, 252, 0.,  0.05886875, -0.03458327, 0.)
#  (253, 253, 0.,  0.05596284, -0.05596284, 0.)
#  (254, 254, 0.,  0.05646233, -0.0739416 , 0.)
#  (255, 255, 0.,  0.05662827, -0.0896222 , 0.)
#  (256, 256, 0.,  0.05442808, -0.10400119, 0.)
#  (257, 257, 0.,  0.0487406 , -0.11738822, 0.)
#  (258, 258, 0.,  0.03903258, -0.12931179, 0.)
#  (259, 259, 0.,  0.02541417, -0.13862116, 0.)
#  (260, 260, 0.,  0.01768759, -0.14383609, 0.)
#  (261, 261, 0.,  0.01998781, -0.10117668, 0.)
#  (262, 262, 0.,  0.02975728, -0.09893162, 0.)
#  (263, 263, 0.,  0.04885343, -0.09445013, 0.)
#  (264, 264, 0.,  0.06677035, -0.08776725, 0.)
#  (265, 265, 0.,  0.08293166, -0.07886861, 0.)
#  (266, 266, 0.,  0.0965344 , -0.06767002, 0.)
#  (267, 267, 0.,  0.1063144 , -0.05429194, 0.)
#  (268, 268, 0.,  0.11047009, -0.03939334, 0.)
#  (269, 269, 0.,  0.1070506 , -0.02547965, 0.)
#  (270, 270, 0.,  0.09626621, -0.01835942, 0.)
#  (271, 271, 0.,  0.08417348, -0.02536766, 0.)
#  (272, 272, 0.,  0.07673394, -0.03979923, 0.)
#  (273, 273, 0.,  0.0739416 , -0.05646233, 0.)
#  (274, 274, 0.,  0.07345859, -0.07345859, 0.)
#  (275, 275, 0.,  0.07284268, -0.09059283, 0.)
#  (276, 276, 0.,  0.07005467, -0.1080617 , 0.)
#  (277, 277, 0.,  0.06340505, -0.125706  , 0.)
#  (278, 278, 0.,  0.05160371, -0.14253945, 0.)
#  (279, 279, 0.,  0.03415081, -0.15649741, 0.)
#  (280, 280, 0.,  0.02401679, -0.16469475, 0.)
#  (281, 281, 0.,  0.01797645, -0.08219706, 0.)
#  (282, 282, 0.,  0.02674563, -0.0803965 , 0.)
#  (283, 283, 0.,  0.04385974, -0.07682255, 0.)
#  (284, 284, 0.,  0.059849  , -0.0715227 , 0.)
#  (285, 285, 0.,  0.0741477 , -0.06463086, 0.)
#  (286, 286, 0.,  0.08613993, -0.05628632, 0.)
#  (287, 287, 0.,  0.0950042 , -0.04696819, 0.)
#  (288, 288, 0.,  0.09985555, -0.03764894, 0.)
#  (289, 289, 0.,  0.10021297, -0.03024194, 0.)
#  (290, 290, 0.,  0.0968686 , -0.02768975, 0.)
#  (291, 291, 0.,  0.09256711, -0.03242218, 0.)
#  (292, 292, 0.,  0.08996342, -0.04278309, 0.)
#  (293, 293, 0.,  0.0896222 , -0.05662827, 0.)
#  (294, 294, 0.,  0.09059283, -0.07284268, 0.)
#  (295, 295, 0.,  0.09123138, -0.09123138, 0.)
#  (296, 296, 0.,  0.08954124, -0.11194793, 0.)
#  (297, 297, 0.,  0.08321835, -0.13483684, 0.)
#  (298, 298, 0.,  0.06982399, -0.15864382, 0.)
#  (299, 299, 0.,  0.04756946, -0.1801289 , 0.)
#  (300, 300, 0.,  0.03408227, -0.19374294, 0.)
#  (301, 301, 0.,  0.01638669, -0.06503645, 0.)
#  (302, 302, 0.,  0.02438277, -0.06364599, 0.)
#  (303, 303, 0.,  0.03997963, -0.0609079 , 0.)
#  (304, 304, 0.,  0.05457866, -0.0569053 , 0.)
#  (305, 305, 0.,  0.06769528, -0.05180424, 0.)
#  (306, 306, 0.,  0.07887173, -0.04589538, 0.)
#  (307, 307, 0.,  0.08767702, -0.03965746, 0.)
#  (308, 308, 0.,  0.09374384, -0.03398037, 0.)
#  (309, 309, 0.,  0.09709142, -0.03014992, 0.)
#  (310, 310, 0.,  0.09844645, -0.02973611, 0.)
#  (311, 311, 0.,  0.09926682, -0.03385516, 0.)
#  (312, 312, 0.,  0.10094003, -0.04228865, 0.)
#  (313, 313, 0.,  0.10400119, -0.05442808, 0.)
#  (314, 314, 0.,  0.1080617 , -0.07005467, 0.)
#  (315, 315, 0.,  0.11194793, -0.08954124, 0.)
#  (316, 316, 0.,  0.11366013, -0.11366013, 0.)
#  (317, 317, 0.,  0.11010094, -0.14304775, 0.)
#  (318, 318, 0.,  0.09689577, -0.17706242, 0.)
#  (319, 319, 0.,  0.06924993, -0.21161708, 0.)
#  (320, 320, 0.,  0.05124487, -0.23640269, 0.)
#  (321, 321, 0.,  0.01519553, -0.04926825, 0.)
#  (322, 322, 0.,  0.02261708, -0.04826689, 0.)
#  (323, 323, 0.,  0.03711905, -0.04625933, 0.)
#  (324, 324, 0.,  0.05074534, -0.04339651, 0.)
#  (325, 325, 0.,  0.06313779, -0.03981062, 0.)
#  (326, 326, 0.,  0.07399315, -0.03581529, 0.)
#  (327, 327, 0.,  0.08308919, -0.03181123, 0.)
#  (328, 328, 0.,  0.09034801, -0.02846717, 0.)
#  (329, 329, 0.,  0.09596871, -0.02663929, 0.)
#  (330, 330, 0.,  0.10057384, -0.02724728, 0.)
#  (331, 331, 0.,  0.10511964, -0.03098053, 0.)
#  (332, 332, 0.,  0.11053634, -0.03809446, 0.)
#  (333, 333, 0.,  0.11738822, -0.0487406 , 0.)
#  (334, 334, 0.,  0.125706  , -0.06340505, 0.)
#  (335, 335, 0.,  0.13483684, -0.08321835, 0.)
#  (336, 336, 0.,  0.14304775, -0.11010094, 0.)
#  (337, 337, 0.,  0.14662064, -0.14662064, 0.)
#  (338, 338, 0.,  0.13839333, -0.1949244 , 0.)
#  (339, 339, 0.,  0.10690973, -0.25286816, 0.)
#  (340, 340, 0.,  0.08365348, -0.30385333, 0.)
#  (341, 341, 0.,  0.01438396, -0.03449286, 0.)
#  (342, 342, 0.,  0.02137385, -0.03385056, 0.)
#  (343, 343, 0.,  0.03510925, -0.03251365, 0.)
#  (344, 344, 0.,  0.04812995, -0.0305936 , 0.)
#  (345, 345, 0.,  0.06011406, -0.02824941, 0.)
#  (346, 346, 0.,  0.07087234, -0.02572159, 0.)
#  (347, 347, 0.,  0.0803289 , -0.02330654, 0.)
#  (348, 348, 0.,  0.0885719 , -0.02144384, 0.)
#  (349, 349, 0.,  0.09587153, -0.02069294, 0.)
#  (350, 350, 0.,  0.1027877 , -0.0216279 , 0.)
#  (351, 351, 0.,  0.110114  , -0.02472703, 0.)
#  (352, 352, 0.,  0.11870009, -0.03037077, 0.)
#  (353, 353, 0.,  0.12931179, -0.03903258, 0.)
#  (354, 354, 0.,  0.14253945, -0.05160371, 0.)
#  (355, 355, 0.,  0.15864382, -0.06982399, 0.)
#  (356, 356, 0.,  0.17706242, -0.09689577, 0.)
#  (357, 357, 0.,  0.1949244 , -0.13839333, 0.)
#  (358, 358, 0.,  0.20314328, -0.20314328, 0.)
#  (359, 359, 0.,  0.17817887, -0.30108801, 0.)
#  (360, 360, 0.,  0.15321522, -0.42227036, 0.)
#  (361, 361, 0.,  0.01391094, -0.02040037, 0.)
#  (362, 362, 0.,  0.02063787, -0.02002424, 0.)
#  (363, 363, 0.,  0.0338621 , -0.01930423, 0.)
#  (364, 364, 0.,  0.04648111, -0.01822426, 0.)
#  (365, 365, 0.,  0.05826577, -0.01689977, 0.)
#  (366, 366, 0.,  0.06905027, -0.01549869, 0.)
#  (367, 367, 0.,  0.07881143, -0.01422618, 0.)
#  (368, 368, 0.,  0.08773441, -0.0133166 , 0.)
#  (369, 369, 0.,  0.09615278, -0.01307829, 0.)
#  (370, 370, 0.,  0.10460792, -0.01384591, 0.)
#  (371, 371, 0.,  0.1138625 , -0.0159242 , 0.)
#  (372, 372, 0.,  0.1248419 , -0.01962651, 0.)
#  (373, 373, 0.,  0.13862116, -0.02541417, 0.)
#  (374, 374, 0.,  0.15649741, -0.03415081, 0.)
#  (375, 375, 0.,  0.1801289 , -0.04756946, 0.)
#  (376, 376, 0.,  0.21161708, -0.06924993, 0.)
#  (377, 377, 0.,  0.25286816, -0.10690973, 0.)
#  (378, 378, 0.,  0.30108801, -0.17817887, 0.)
#  (379, 379, 0.,  0.32603681, -0.32603681, 0.)
#  (380, 380, 0.,  0.32601817, -0.66188488, 0.)
#  (381, 381, 0.,  0.01363169, -0.01349533, 0.)
#  (382, 382, 0.,  0.02027771, -0.01321608, 0.)
#  (383, 383, 0.,  0.03330928, -0.012775  , 0.)
#  (384, 384, 0.,  0.04572548, -0.01211044, 0.)
#  (385, 385, 0.,  0.05738849, -0.01126374, 0.)
#  (386, 386, 0.,  0.06819875, -0.01035587, 0.)
#  (387, 387, 0.,  0.07814681, -0.0095607 , 0.)
#  (388, 388, 0.,  0.08742401, -0.00902662, 0.)
#  (389, 389, 0.,  0.09640084, -0.00893989, 0.)
#  (390, 390, 0.,  0.10563361, -0.00952274, 0.)
#  (391, 391, 0.,  0.1158946 , -0.01099126, 0.)
#  (392, 392, 0.,  0.12819007, -0.01358693, 0.)
#  (393, 393, 0.,  0.14383609, -0.01768759, 0.)
#  (394, 394, 0.,  0.16469475, -0.02401679, 0.)
#  (395, 395, 0.,  0.19374294, -0.03408227, 0.)
#  (396, 396, 0.,  0.23640269, -0.05124487, 0.)
#  (397, 397, 0.,  0.30385333, -0.08365348, 0.)
#  (398, 398, 0.,  0.42227036, -0.15321522, 0.)
#  (399, 399, 0.,  0.66188488, -0.32601817, 0.)
#  (400, 400, 0.,  0.82491137, -0.82491137, 0.)]

# %% [markdown]
# ## Paso 14. Visualización.
#
# Podemos usar las herramientas de visualización de flopy

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
qx, qy, qz = flopy.utils.postprocessing.get_specific_discharge(spdis, gwf)
fig, ax = plt.subplots(2,2, figsize=(10,10))
ax[0,0].set_aspect('equal')
ax[0,1].set_aspect('equal')
ax[1,0].set_aspect('equal')
ax[1,1].set_aspect('equal')

pmv0 = flopy.plot.PlotMapView(gwf, ax=ax[0,0])
pmv0.plot_grid(colors='dimgray', lw=0.5)

pmv1 = flopy.plot.PlotMapView(gwf, ax=ax[0,1])
pmv1.plot_array(head)
pmv1.contour_array(head, levels=10, colors='white', linewidths=1.)

pmv2 = flopy.plot.PlotMapView(gwf, ax=ax[1,0])
pmv2.plot_vector(qx, qy, normalize=False, color="k")

print(qx[0].shape)
Lx = nrow
Ly = ncol
delc = Lx / ncol
delr = Ly / nrow
# Malla donde se dibuja la velocidad
x = np.linspace(0, Lx, ncol)
y = np.linspace(0, Ly, nrow)
xg, yg = np.meshgrid(x,y)
ax[1,1].streamplot(xg,yg,qx[0],qy[0], color='k')
ax[1,1].set_xlim((0,Lx))
ax[1,1].set_ylim(0,Ly)
# Out:
# (20, 20)
# (0.0, 20.0)

# %% [markdown]
# ### Visualización con matplotlib

# %%
# Calculamos la velocidad usando la Ley de Darcy.
vx = np.zeros((nrow-1, ncol-1))
vy = np.zeros((nrow-1, ncol-1))

kx = ky = 10
delc = Lx / ncol
delr = Ly / nrow

for i in range(0,nrow-1):
    for j in range(0,ncol-1):
        vx[i,j] = - kx * (head[0,i,j+1] - head[0,i,j]) / delc
        vy[i,j] = - ky * (head[0,i+1,j] - head[0,i,j]) / delr

# Malla donde se dibuja la velocidad
x = np.linspace(0+delc*0.5, Lx - delc*0.5, ncol - 1)
y = np.linspace(0+delr*0.5, Ly - delr*0.5, nrow - 1)
xg, yg = np.meshgrid(x,y)

# %%
levels = np.linspace(0.,10.,51)
extent = (0,Lx,0,Ly)
salto = 4
mapa_color='GnBu'

plt.figure(figsize=(15,6))

plt.subplot(131)
cf = plt.contourf(head[0, :, :], levels=levels, extent=extent, cmap=mapa_color)
cl = plt.contour(head[0, :, :], levels=levels[1:-1:salto], extent=extent, colors='black', linewidths=1.0)
plt.clabel(cl, inline=1, fontsize=10)
plt.gca().set_aspect('equal')
plt.colorbar(cf, orientation='horizontal', label='$h$')
plt.title('Carga hidráulica')

plt.subplot(132)
cf = plt.contourf(vx, levels=30, extent=extent, cmap='coolwarm')
plt.quiver(xg,yg,vx,vy)
plt.xlim((0,Lx))
plt.ylim(0,Ly)
plt.gca().set_aspect('equal')
plt.colorbar(cf, orientation='horizontal', label='$v_x$')
plt.title('Velocidad')

plt.subplot(133)
cf = plt.contourf(vy, levels=30, extent=extent, cmap='Greys')
plt.streamplot(xg,yg,vx,vy, color='k')
plt.xlim((0,Lx))
plt.ylim(0,Ly)
plt.gca().set_aspect('equal')
plt.colorbar(cf, orientation='horizontal', label='$v_y$')
plt.title('Líneas de flujo')

#plt.savefig('mf6_vis.pdf')
# Out:
# Text(0.5, 1.0, 'Líneas de flujo')
