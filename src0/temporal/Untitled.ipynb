# %%
# -*- coding: utf-8 -*-
"""
Created on Mon Mar  4 08:40:19 2024

@author: leo_teja
"""


import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.sparse import lil_matrix           #Importación del modulo scipy que convierte una matriz en una lista
from scipy.sparse import csr_matrix           #Importación del modulo csr_matrix para emplear el método CSR para la solución del sistema de ecuaciones
from scipy.sparse.linalg import spsolve  

from time import time                         #Importación del modulo time para determinar los tiempos de cálculo

#------------------------------------------------------------------------------------------#
#------------- Datos de entrada: Fuente hoja de cálculo excel WMA -------------------------#
#------------------------------------------------------------------------------------------#
import sys

long_x = 15.0                         #Longitud en "x" en [ft]
teta = 1.0                            #Adimensional [Adim.]
DH = 1.0                              #coefciente de difusión??? [m2/dia]
r = -0.02                             #recarga o descarga  [1/dia]
cr = 0.0                              #concentración de recarga [Adim.]
nds_x = 30                            #Cantidad de nodos en "x"
t_sim = 50.8                          #Tiempo de simulación (dias)
#dt = 0.4                              #Paso de tiempo (dias)
dt = 0.1                              #Paso de tiempo (dias)
# dt = 0.01                              #Paso de tiempo (dias)
q_inf = 1.0                           #Condición de frontera izquierda en [m/dia]
c_inf = 0.0                           #Condición de frontera izquierda en [m/dia]
c_out = 0.0                           #Condición de frontera derecha en [m/dia]
long_ini_cini = 1.0                   #Posición inicial de las condiciones iniciales de concentraciones en [ft]
long_fin_cini = 7.5                   #Posición final de las condiciones iniciales de concentraciones en [ft]

#------------------------------------------------------------------------------------------#
#--------------------------- Malla de simulación espcio y tiempo ----------------------------#
#------------------------------------------------------------------------------------------#

delta_x = long_x/nds_x                                           #Delta en "x" considerando un espaciamiento homogéneo entre nodos en [m]
xi = np.linspace((delta_x)/(2), long_x-(delta_x/2), nds_x)        #Posición de los nodos en "i" en [m]
x_frntrs = np.linspace(0, long_x, nds_x+1)                      #Posición de las fronteras "i+1/2 e i-1/2" en [m]

t = np.arange(0, t_sim+0.01, dt)           #Vector de tiempo en [Días]
nt = len(t)-1                             #numero de pasos de tiempo 

#------------------------------------------------------------------------------------------#
#---------- Calculando los valores de q para cada nodo y fronteras de la celdas ----------------#
#------------------------------------------------------------------------------------------#

q_frnts = np.zeros(nds_x+1)                       #Vector de q en las fronteras de las celdas en [m/dias]
q_i = np.zeros(nds_x)                             #Vector de q en los nodos o centros "i" en [m/dias]
for i in range(0, nds_x+1):
    if i == 0:
        q_frnts[i] = q_inf                        #Valor de q en 0-1/2 de la primera frontera (que sería la condición de frontera izquierda de qinf)
    else:
        q_frnts[i] = q_frnts[i-1]+(r*delta_x)    #Valor de q en las demás fronteras en i-1/2, i+1/2 
        q_i[i-1] = (q_frnts[i-1]+q_frnts[i])/2   #Valor de q en los nodos i


#------------------------------------------------------------------------------------------#
#------ Definiendo vectores y matriz  para el sistema de eq lineales ---------------------#
#------------------------------------------------------------------------------------------#

Beta_W = np.zeros(nds_x); Beta_C = np.zeros(nds_x); Beta_E = np.zeros(nds_x); Beta_r = np.zeros(nds_x)                          
Lambda_W = np.zeros(nds_x); Lambda_C = np.zeros(nds_x); Lambda_E = np.zeros(nds_x); Lambda_r = np.zeros(nds_x)
A = np.zeros((nds_x, nds_x))          #Matriz de coeficientes A
R = np.identity(nds_x)*r
Q = np.zeros((nds_x,nds_x))
D = np.identity(nds_x)*teta

c_ini = np.zeros(nds_x)                       #Vector de condiciones iniciales de c
c_n = np.zeros(nds_x)                         #Vector de valor de c a un paso de tiempo n (necesario para la solución del sistema de ecuaciones)
c_v = np.zeros(nds_x)                         #Vector de valor de c a un paso de tiempo n+1
solcns_c = np.zeros((nt+1, nds_x))            #Matriz de guardado de las c para cada paso de tiempo y en toda la malla 1D (incluyendo las condiciones iniciales al tiempo cero)

#------------------------------------------------------------------------------------------#
#---------------------------- Definiendo condiciones iniciales ----------------------------#
#------------------------------------------------------------------------------------------#

for i in range(0, nds_x):
    if xi[i] >= long_ini_cini and xi[i] <= long_fin_cini:   #Si los nodos en xi están dentro de este rango se tiene la condición inicial de c = 1
        c_ini[i] = 1
    else:
        c_ini[i] = 0                          #Si los nodos en xi no se encuentran dentro del rango se tiene la condición inicial de c = 0

c_n[:] = c_ini[:]                             #Inicializando el vector c_n
solcns_c[0][:] = c_n[:]                       #Guardando el valor de las condiciones iniciales en la matriz de soluciones de c

#------------------------------------------------------------------------------------------#
#------------------------ Inicio del ciclo solución en el tiempo --------------------------#
#------------------------------------------------------------------------------------------#
tiempoComputo_inicial = time()       

for ti in range(0, nt):
        
    #--------------------------------------------------------------------------------------#
    #-- Calculando los coeficientes "A" Y las matrices diagonales D, R, Q, --------#
    #--------------------------------------------------------------------------------------# 
    
    Q[0][0]=q_inf/delta_x
    
    for i in range(0, nds_x): 
        if ((i>0)and(i<nds_x-1)):
            A[i][i+1]= -q_frnts[i+1]/(2*delta_x)+DH/(delta_x**2)  
            A[i][i]=   (q_frnts[i+1]-q_frnts[i])/(2*delta_x)-(2*DH)/(delta_x**2)
            A[i][i-1]=  q_frnts[i]/(2*delta_x)+DH/(delta_x**2)

        if i==0:
            A[i][i+1]= -q_frnts[i+1]/(2*delta_x)+DH/(delta_x**2)
            A[i][i]=    q_frnts[i+1]/(2*delta_x)-DH/(delta_x**2)

        if i==nds_x-1:
            A[i][i]=   -q_frnts[i]/(2*delta_x)-DH/(delta_x**2)
            A[i][i-1]=  q_frnts[i]/(2*delta_x)+DH/(delta_x**2)
        
        A[i][i]=-R[i][i]-Q[i][i]+A[i][i]
    
      
    cr_vec=np.ones(nds_x)*cr
    cinf_vec=np.ones(nds_x)*c_inf

    sumaMat=np.dot(A,c_n)+np.dot(R,cr_vec)+np.dot(Q,cinf_vec)   #OPERACIONES DE LA MATRICIALES DE POWER POINT 
    c_v=c_n+dt*(np.linalg.inv(D).dot(sumaMat))
    
    solcns_c[ti+1][:] = c_v[:]  
    c_n[:] = c_v[:]                                                                         #Guardando el valor de c al tiempo n que se utilizará en el siguiente paso de tiempo

    print("tiempo de simulacion: " +str(round(dt*(ti+1),2))+" dias" )


#------------------------------------------------------------------------------------------#
#---------------------- Tiempo de ejecución del modelo de simulación ----------------------#
#------------------------------------------------------------------------------------------# 

tiempoComputo_final=time()                                                                         #Toma el valor de tiempo final de ejecución, para  calcuar el tiempo total de la simulación
tiempo_ejec_seg=(tiempoComputo_final-tiempoComputo_inicial)                                               #Calcula el tiempo total de simulación, pasado a segundos
tiempo_ejec_min=(tiempoComputo_final-tiempoComputo_inicial)/60                                            #Calcula el tiempo total de simulación, pasado a minutos
print("\nTiempo de Ejecución:",tiempo_ejec_seg, "[Segundos]","\t", tiempo_ejec_min, "[Minutos]\n")
print("|------------------------------------------------------------------------------|")
print("|-------------------------- FIN DE LA SIMULACIÓN xdxd -------------------------|")
print("|------------------------------------------------------------------------------|")

#------------------------------------------------------------------------------------------#
#--------------------------- Graficando todos los resultados ------------------------------#
#------------------------------------------------------------------------------------------#

plt.figure('Graf_cs',figsize=(9,8))
plt.style.use('fast')
plt.minorticks_on()
plt.title('Perfil de c vs distancia en el tiempo')
for i in range(0, nt+1):
    plt.plot(xi, solcns_c[i][:]) 
# plt.legend(loc=4)
plt.xlabel("Distancia x [$m$]")
plt.ylabel("Concentraciones [$adim$]")                                                                        
plt.grid(True,which='major', color='w', linestyle='-')
plt.grid(True, which='minor', color='w', linestyle='--')



WMA_I=pd.read_excel('comparativa.xlsx', sheet_name='WMA_I')     #Crea un data frame llamado WMA_I a partir de la tabla de excel
data_set = WMA_I.iloc[13:,9:39].to_numpy()

plt.figure('Graf2_1r', figsize=(12,8))
plt.title('Comparativa explícito vs condicion inicial')
tsel=10    #tiempo seleccionado de hoja excel
multiplo=int(0.4/dt)
if multiplo==1:
    tselExp=tsel
else:
    tselExp=multiplo*tsel

lgImp=str(round(tsel*0.4,2))
lgExp=str(round(tselExp*dt,2))
plt.plot(xi, solcns_c[0][:], "-r"  , label="Condicion inicial")
plt.plot(xi, solcns_c[tselExp][:], "-r*", label="Tiempo de simulacion "+lgExp+" dias este nootebook")
plt.plot(xi, data_set[tsel][:], "-.*m", label="Tiempo de simulacion "+lgImp+" dias WMA_I" )
plt.xlabel("Distancia x [$m$]"), plt.ylabel("c $[adim]$")
plt.legend(loc=0); plt.minorticks_on()
plt.grid(True,which='major', color='w', linestyle='-')
plt.grid(True, which='minor', color='g', linestyle='--')
# Out:
# tiempo de simulacion: 0.1 dias
# tiempo de simulacion: 0.2 dias
# tiempo de simulacion: 0.3 dias
# tiempo de simulacion: 0.4 dias
# tiempo de simulacion: 0.5 dias
# tiempo de simulacion: 0.6 dias
# tiempo de simulacion: 0.7 dias
# tiempo de simulacion: 0.8 dias
# tiempo de simulacion: 0.9 dias
# tiempo de simulacion: 1.0 dias
# tiempo de simulacion: 1.1 dias
# tiempo de simulacion: 1.2 dias
# tiempo de simulacion: 1.3 dias
# tiempo de simulacion: 1.4 dias
# tiempo de simulacion: 1.5 dias
# tiempo de simulacion: 1.6 dias
# tiempo de simulacion: 1.7 dias
# tiempo de simulacion: 1.8 dias
# tiempo de simulacion: 1.9 dias
# tiempo de simulacion: 2.0 dias
# tiempo de simulacion: 2.1 dias
# tiempo de simulacion: 2.2 dias
# tiempo de simulacion: 2.3 dias
# tiempo de simulacion: 2.4 dias
# tiempo de simulacion: 2.5 dias
# tiempo de simulacion: 2.6 dias
# tiempo de simulacion: 2.7 dias
# tiempo de simulacion: 2.8 dias
# tiempo de simulacion: 2.9 dias
# tiempo de simulacion: 3.0 dias
# tiempo de simulacion: 3.1 dias
# tiempo de simulacion: 3.2 dias
# tiempo de simulacion: 3.3 dias
# tiempo de simulacion: 3.4 dias
# tiempo de simulacion: 3.5 dias
# tiempo de simulacion: 3.6 dias
# tiempo de simulacion: 3.7 dias
# tiempo de simulacion: 3.8 dias
# tiempo de simulacion: 3.9 dias
# tiempo de simulacion: 4.0 dias
# tiempo de simulacion: 4.1 dias
# tiempo de simulacion: 4.2 dias
# tiempo de simulacion: 4.3 dias
# tiempo de simulacion: 4.4 dias
# tiempo de simulacion: 4.5 dias
# tiempo de simulacion: 4.6 dias
# tiempo de simulacion: 4.7 dias
# tiempo de simulacion: 4.8 dias
# tiempo de simulacion: 4.9 dias
# tiempo de simulacion: 5.0 dias
# tiempo de simulacion: 5.1 dias
# tiempo de simulacion: 5.2 dias
# tiempo de simulacion: 5.3 dias
# tiempo de simulacion: 5.4 dias
# tiempo de simulacion: 5.5 dias
# tiempo de simulacion: 5.6 dias
# tiempo de simulacion: 5.7 dias
# tiempo de simulacion: 5.8 dias
# tiempo de simulacion: 5.9 dias
# tiempo de simulacion: 6.0 dias
# tiempo de simulacion: 6.1 dias
# tiempo de simulacion: 6.2 dias
# tiempo de simulacion: 6.3 dias
# tiempo de simulacion: 6.4 dias
# tiempo de simulacion: 6.5 dias
# tiempo de simulacion: 6.6 dias
# tiempo de simulacion: 6.7 dias
# tiempo de simulacion: 6.8 dias
# tiempo de simulacion: 6.9 dias
# tiempo de simulacion: 7.0 dias
# tiempo de simulacion: 7.1 dias
# tiempo de simulacion: 7.2 dias
# tiempo de simulacion: 7.3 dias
# tiempo de simulacion: 7.4 dias
# tiempo de simulacion: 7.5 dias
# tiempo de simulacion: 7.6 dias
# tiempo de simulacion: 7.7 dias
# tiempo de simulacion: 7.8 dias
# tiempo de simulacion: 7.9 dias
# tiempo de simulacion: 8.0 dias
# tiempo de simulacion: 8.1 dias
# tiempo de simulacion: 8.2 dias
# tiempo de simulacion: 8.3 dias
# tiempo de simulacion: 8.4 dias
# tiempo de simulacion: 8.5 dias
# tiempo de simulacion: 8.6 dias
# tiempo de simulacion: 8.7 dias
# tiempo de simulacion: 8.8 dias
# tiempo de simulacion: 8.9 dias
# tiempo de simulacion: 9.0 dias
# tiempo de simulacion: 9.1 dias
# tiempo de simulacion: 9.2 dias
# tiempo de simulacion: 9.3 dias
# tiempo de simulacion: 9.4 dias
# tiempo de simulacion: 9.5 dias
# tiempo de simulacion: 9.6 dias
# tiempo de simulacion: 9.7 dias
# tiempo de simulacion: 9.8 dias
# tiempo de simulacion: 9.9 dias
# tiempo de simulacion: 10.0 dias
# tiempo de simulacion: 10.1 dias
# tiempo de simulacion: 10.2 dias
# tiempo de simulacion: 10.3 dias
# tiempo de simulacion: 10.4 dias
# tiempo de simulacion: 10.5 dias
# tiempo de simulacion: 10.6 dias
# tiempo de simulacion: 10.7 dias
# tiempo de simulacion: 10.8 dias
# tiempo de simulacion: 10.9 dias
# tiempo de simulacion: 11.0 dias
# tiempo de simulacion: 11.1 dias
# tiempo de simulacion: 11.2 dias
# tiempo de simulacion: 11.3 dias
# tiempo de simulacion: 11.4 dias
# tiempo de simulacion: 11.5 dias
# tiempo de simulacion: 11.6 dias
# tiempo de simulacion: 11.7 dias
# tiempo de simulacion: 11.8 dias
# tiempo de simulacion: 11.9 dias
# tiempo de simulacion: 12.0 dias
# tiempo de simulacion: 12.1 dias
# tiempo de simulacion: 12.2 dias
# tiempo de simulacion: 12.3 dias
# tiempo de simulacion: 12.4 dias
# tiempo de simulacion: 12.5 dias
# tiempo de simulacion: 12.6 dias
# tiempo de simulacion: 12.7 dias
# tiempo de simulacion: 12.8 dias
# tiempo de simulacion: 12.9 dias
# tiempo de simulacion: 13.0 dias
# tiempo de simulacion: 13.1 dias
# tiempo de simulacion: 13.2 dias
# tiempo de simulacion: 13.3 dias
# tiempo de simulacion: 13.4 dias
# tiempo de simulacion: 13.5 dias
# tiempo de simulacion: 13.6 dias
# tiempo de simulacion: 13.7 dias
# tiempo de simulacion: 13.8 dias
# tiempo de simulacion: 13.9 dias
# tiempo de simulacion: 14.0 dias
# tiempo de simulacion: 14.1 dias
# tiempo de simulacion: 14.2 dias
# tiempo de simulacion: 14.3 dias
# tiempo de simulacion: 14.4 dias
# tiempo de simulacion: 14.5 dias
# tiempo de simulacion: 14.6 dias
# tiempo de simulacion: 14.7 dias
# tiempo de simulacion: 14.8 dias
# tiempo de simulacion: 14.9 dias
# tiempo de simulacion: 15.0 dias
# tiempo de simulacion: 15.1 dias
# tiempo de simulacion: 15.2 dias
# tiempo de simulacion: 15.3 dias
# tiempo de simulacion: 15.4 dias
# tiempo de simulacion: 15.5 dias
# tiempo de simulacion: 15.6 dias
# tiempo de simulacion: 15.7 dias
# tiempo de simulacion: 15.8 dias
# tiempo de simulacion: 15.9 dias
# tiempo de simulacion: 16.0 dias
# tiempo de simulacion: 16.1 dias
# tiempo de simulacion: 16.2 dias
# tiempo de simulacion: 16.3 dias
# tiempo de simulacion: 16.4 dias
# tiempo de simulacion: 16.5 dias
# tiempo de simulacion: 16.6 dias
# tiempo de simulacion: 16.7 dias
# tiempo de simulacion: 16.8 dias
# tiempo de simulacion: 16.9 dias
# tiempo de simulacion: 17.0 dias
# tiempo de simulacion: 17.1 dias
# tiempo de simulacion: 17.2 dias
# tiempo de simulacion: 17.3 dias
# tiempo de simulacion: 17.4 dias
# tiempo de simulacion: 17.5 dias
# tiempo de simulacion: 17.6 dias
# tiempo de simulacion: 17.7 dias
# tiempo de simulacion: 17.8 dias
# tiempo de simulacion: 17.9 dias
# tiempo de simulacion: 18.0 dias
# tiempo de simulacion: 18.1 dias
# tiempo de simulacion: 18.2 dias
# tiempo de simulacion: 18.3 dias
# tiempo de simulacion: 18.4 dias
# tiempo de simulacion: 18.5 dias
# tiempo de simulacion: 18.6 dias
# tiempo de simulacion: 18.7 dias
# tiempo de simulacion: 18.8 dias
# tiempo de simulacion: 18.9 dias
# tiempo de simulacion: 19.0 dias
# tiempo de simulacion: 19.1 dias
# tiempo de simulacion: 19.2 dias
# tiempo de simulacion: 19.3 dias
# tiempo de simulacion: 19.4 dias
# tiempo de simulacion: 19.5 dias
# tiempo de simulacion: 19.6 dias
# tiempo de simulacion: 19.7 dias
# tiempo de simulacion: 19.8 dias
# tiempo de simulacion: 19.9 dias
# tiempo de simulacion: 20.0 dias
# tiempo de simulacion: 20.1 dias
# tiempo de simulacion: 20.2 dias
# tiempo de simulacion: 20.3 dias
# tiempo de simulacion: 20.4 dias
# tiempo de simulacion: 20.5 dias
# tiempo de simulacion: 20.6 dias
# tiempo de simulacion: 20.7 dias
# tiempo de simulacion: 20.8 dias
# tiempo de simulacion: 20.9 dias
# tiempo de simulacion: 21.0 dias
# tiempo de simulacion: 21.1 dias
# tiempo de simulacion: 21.2 dias
# tiempo de simulacion: 21.3 dias
# tiempo de simulacion: 21.4 dias
# tiempo de simulacion: 21.5 dias
# tiempo de simulacion: 21.6 dias
# tiempo de simulacion: 21.7 dias
# tiempo de simulacion: 21.8 dias
# tiempo de simulacion: 21.9 dias
# tiempo de simulacion: 22.0 dias
# tiempo de simulacion: 22.1 dias
# tiempo de simulacion: 22.2 dias
# tiempo de simulacion: 22.3 dias
# tiempo de simulacion: 22.4 dias
# tiempo de simulacion: 22.5 dias
# tiempo de simulacion: 22.6 dias
# tiempo de simulacion: 22.7 dias
# tiempo de simulacion: 22.8 dias
# tiempo de simulacion: 22.9 dias
# tiempo de simulacion: 23.0 dias
# tiempo de simulacion: 23.1 dias
# tiempo de simulacion: 23.2 dias
# tiempo de simulacion: 23.3 dias
# tiempo de simulacion: 23.4 dias
# tiempo de simulacion: 23.5 dias
# tiempo de simulacion: 23.6 dias
# tiempo de simulacion: 23.7 dias
# tiempo de simulacion: 23.8 dias
# tiempo de simulacion: 23.9 dias
# tiempo de simulacion: 24.0 dias
# tiempo de simulacion: 24.1 dias
# tiempo de simulacion: 24.2 dias
# tiempo de simulacion: 24.3 dias
# tiempo de simulacion: 24.4 dias
# tiempo de simulacion: 24.5 dias
# tiempo de simulacion: 24.6 dias
# tiempo de simulacion: 24.7 dias
# tiempo de simulacion: 24.8 dias
# tiempo de simulacion: 24.9 dias
# tiempo de simulacion: 25.0 dias
# tiempo de simulacion: 25.1 dias
# tiempo de simulacion: 25.2 dias
# tiempo de simulacion: 25.3 dias
# tiempo de simulacion: 25.4 dias
# tiempo de simulacion: 25.5 dias
# tiempo de simulacion: 25.6 dias
# tiempo de simulacion: 25.7 dias
# tiempo de simulacion: 25.8 dias
# tiempo de simulacion: 25.9 dias
# tiempo de simulacion: 26.0 dias
# tiempo de simulacion: 26.1 dias
# tiempo de simulacion: 26.2 dias
# tiempo de simulacion: 26.3 dias
# tiempo de simulacion: 26.4 dias
# tiempo de simulacion: 26.5 dias
# tiempo de simulacion: 26.6 dias
# tiempo de simulacion: 26.7 dias
# tiempo de simulacion: 26.8 dias
# tiempo de simulacion: 26.9 dias
# tiempo de simulacion: 27.0 dias
# tiempo de simulacion: 27.1 dias
# tiempo de simulacion: 27.2 dias
# tiempo de simulacion: 27.3 dias
# tiempo de simulacion: 27.4 dias
# tiempo de simulacion: 27.5 dias
# tiempo de simulacion: 27.6 dias
# tiempo de simulacion: 27.7 dias
# tiempo de simulacion: 27.8 dias
# tiempo de simulacion: 27.9 dias
# tiempo de simulacion: 28.0 dias
# tiempo de simulacion: 28.1 dias
# tiempo de simulacion: 28.2 dias
# tiempo de simulacion: 28.3 dias
# tiempo de simulacion: 28.4 dias
# tiempo de simulacion: 28.5 dias
# tiempo de simulacion: 28.6 dias
# tiempo de simulacion: 28.7 dias
# tiempo de simulacion: 28.8 dias
# tiempo de simulacion: 28.9 dias
# tiempo de simulacion: 29.0 dias
# tiempo de simulacion: 29.1 dias
# tiempo de simulacion: 29.2 dias
# tiempo de simulacion: 29.3 dias
# tiempo de simulacion: 29.4 dias
# tiempo de simulacion: 29.5 dias
# tiempo de simulacion: 29.6 dias
# tiempo de simulacion: 29.7 dias
# tiempo de simulacion: 29.8 dias
# tiempo de simulacion: 29.9 dias
# tiempo de simulacion: 30.0 dias
# tiempo de simulacion: 30.1 dias
# tiempo de simulacion: 30.2 dias
# tiempo de simulacion: 30.3 dias
# tiempo de simulacion: 30.4 dias
# tiempo de simulacion: 30.5 dias
# tiempo de simulacion: 30.6 dias
# tiempo de simulacion: 30.7 dias
# tiempo de simulacion: 30.8 dias
# tiempo de simulacion: 30.9 dias
# tiempo de simulacion: 31.0 dias
# tiempo de simulacion: 31.1 dias
# tiempo de simulacion: 31.2 dias
# tiempo de simulacion: 31.3 dias
# tiempo de simulacion: 31.4 dias
# tiempo de simulacion: 31.5 dias
# tiempo de simulacion: 31.6 dias
# tiempo de simulacion: 31.7 dias
# tiempo de simulacion: 31.8 dias
# tiempo de simulacion: 31.9 dias
# tiempo de simulacion: 32.0 dias
# tiempo de simulacion: 32.1 dias
# tiempo de simulacion: 32.2 dias
# tiempo de simulacion: 32.3 dias
# tiempo de simulacion: 32.4 dias
# tiempo de simulacion: 32.5 dias
# tiempo de simulacion: 32.6 dias
# tiempo de simulacion: 32.7 dias
# tiempo de simulacion: 32.8 dias
# tiempo de simulacion: 32.9 dias
# tiempo de simulacion: 33.0 dias
# tiempo de simulacion: 33.1 dias
# tiempo de simulacion: 33.2 dias
# tiempo de simulacion: 33.3 dias
# tiempo de simulacion: 33.4 dias
# tiempo de simulacion: 33.5 dias
# tiempo de simulacion: 33.6 dias
# tiempo de simulacion: 33.7 dias
# tiempo de simulacion: 33.8 dias
# tiempo de simulacion: 33.9 dias
# tiempo de simulacion: 34.0 dias
# tiempo de simulacion: 34.1 dias
# tiempo de simulacion: 34.2 dias
# tiempo de simulacion: 34.3 dias
# tiempo de simulacion: 34.4 dias
# tiempo de simulacion: 34.5 dias
# tiempo de simulacion: 34.6 dias
# tiempo de simulacion: 34.7 dias
# tiempo de simulacion: 34.8 dias
# tiempo de simulacion: 34.9 dias
# tiempo de simulacion: 35.0 dias
# tiempo de simulacion: 35.1 dias
# tiempo de simulacion: 35.2 dias
# tiempo de simulacion: 35.3 dias
# tiempo de simulacion: 35.4 dias
# tiempo de simulacion: 35.5 dias
# tiempo de simulacion: 35.6 dias
# tiempo de simulacion: 35.7 dias
# tiempo de simulacion: 35.8 dias
# tiempo de simulacion: 35.9 dias
# tiempo de simulacion: 36.0 dias
# tiempo de simulacion: 36.1 dias
# tiempo de simulacion: 36.2 dias
# tiempo de simulacion: 36.3 dias
# tiempo de simulacion: 36.4 dias
# tiempo de simulacion: 36.5 dias
# tiempo de simulacion: 36.6 dias
# tiempo de simulacion: 36.7 dias
# tiempo de simulacion: 36.8 dias
# tiempo de simulacion: 36.9 dias
# tiempo de simulacion: 37.0 dias
# tiempo de simulacion: 37.1 dias
# tiempo de simulacion: 37.2 dias
# tiempo de simulacion: 37.3 dias
# tiempo de simulacion: 37.4 dias
# tiempo de simulacion: 37.5 dias
# tiempo de simulacion: 37.6 dias
# tiempo de simulacion: 37.7 dias
# tiempo de simulacion: 37.8 dias
# tiempo de simulacion: 37.9 dias
# tiempo de simulacion: 38.0 dias
# tiempo de simulacion: 38.1 dias
# tiempo de simulacion: 38.2 dias
# tiempo de simulacion: 38.3 dias
# tiempo de simulacion: 38.4 dias
# tiempo de simulacion: 38.5 dias
# tiempo de simulacion: 38.6 dias
# tiempo de simulacion: 38.7 dias
# tiempo de simulacion: 38.8 dias
# tiempo de simulacion: 38.9 dias
# tiempo de simulacion: 39.0 dias
# tiempo de simulacion: 39.1 dias
# tiempo de simulacion: 39.2 dias
# tiempo de simulacion: 39.3 dias
# tiempo de simulacion: 39.4 dias
# tiempo de simulacion: 39.5 dias
# tiempo de simulacion: 39.6 dias
# tiempo de simulacion: 39.7 dias
# tiempo de simulacion: 39.8 dias
# tiempo de simulacion: 39.9 dias
# tiempo de simulacion: 40.0 dias
# tiempo de simulacion: 40.1 dias
# tiempo de simulacion: 40.2 dias
# tiempo de simulacion: 40.3 dias
# tiempo de simulacion: 40.4 dias
# tiempo de simulacion: 40.5 dias
# tiempo de simulacion: 40.6 dias
# tiempo de simulacion: 40.7 dias
# tiempo de simulacion: 40.8 dias
# tiempo de simulacion: 40.9 dias
# tiempo de simulacion: 41.0 dias
# tiempo de simulacion: 41.1 dias
# tiempo de simulacion: 41.2 dias
# tiempo de simulacion: 41.3 dias
# tiempo de simulacion: 41.4 dias
# tiempo de simulacion: 41.5 dias
# tiempo de simulacion: 41.6 dias
# tiempo de simulacion: 41.7 dias
# tiempo de simulacion: 41.8 dias
# tiempo de simulacion: 41.9 dias
# tiempo de simulacion: 42.0 dias
# tiempo de simulacion: 42.1 dias
# tiempo de simulacion: 42.2 dias
# tiempo de simulacion: 42.3 dias
# tiempo de simulacion: 42.4 dias
# tiempo de simulacion: 42.5 dias
# tiempo de simulacion: 42.6 dias
# tiempo de simulacion: 42.7 dias
# tiempo de simulacion: 42.8 dias
# tiempo de simulacion: 42.9 dias
# tiempo de simulacion: 43.0 dias
# tiempo de simulacion: 43.1 dias
# tiempo de simulacion: 43.2 dias
# tiempo de simulacion: 43.3 dias
# tiempo de simulacion: 43.4 dias
# tiempo de simulacion: 43.5 dias
# tiempo de simulacion: 43.6 dias
# tiempo de simulacion: 43.7 dias
# tiempo de simulacion: 43.8 dias
# tiempo de simulacion: 43.9 dias
# tiempo de simulacion: 44.0 dias
# tiempo de simulacion: 44.1 dias
# tiempo de simulacion: 44.2 dias
# tiempo de simulacion: 44.3 dias
# tiempo de simulacion: 44.4 dias
# tiempo de simulacion: 44.5 dias
# tiempo de simulacion: 44.6 dias
# tiempo de simulacion: 44.7 dias
# tiempo de simulacion: 44.8 dias
# tiempo de simulacion: 44.9 dias
# tiempo de simulacion: 45.0 dias
# tiempo de simulacion: 45.1 dias
# tiempo de simulacion: 45.2 dias
# tiempo de simulacion: 45.3 dias
# tiempo de simulacion: 45.4 dias
# tiempo de simulacion: 45.5 dias
# tiempo de simulacion: 45.6 dias
# tiempo de simulacion: 45.7 dias
# tiempo de simulacion: 45.8 dias
# tiempo de simulacion: 45.9 dias
# tiempo de simulacion: 46.0 dias
# tiempo de simulacion: 46.1 dias
# tiempo de simulacion: 46.2 dias
# tiempo de simulacion: 46.3 dias
# tiempo de simulacion: 46.4 dias
# tiempo de simulacion: 46.5 dias
# tiempo de simulacion: 46.6 dias
# tiempo de simulacion: 46.7 dias
# tiempo de simulacion: 46.8 dias
# tiempo de simulacion: 46.9 dias
# tiempo de simulacion: 47.0 dias
# tiempo de simulacion: 47.1 dias
# tiempo de simulacion: 47.2 dias
# tiempo de simulacion: 47.3 dias
# tiempo de simulacion: 47.4 dias
# tiempo de simulacion: 47.5 dias
# tiempo de simulacion: 47.6 dias
# tiempo de simulacion: 47.7 dias
# tiempo de simulacion: 47.8 dias
# tiempo de simulacion: 47.9 dias
# tiempo de simulacion: 48.0 dias
# tiempo de simulacion: 48.1 dias
# tiempo de simulacion: 48.2 dias
# tiempo de simulacion: 48.3 dias
# tiempo de simulacion: 48.4 dias
# tiempo de simulacion: 48.5 dias
# tiempo de simulacion: 48.6 dias
# tiempo de simulacion: 48.7 dias
# tiempo de simulacion: 48.8 dias
# tiempo de simulacion: 48.9 dias
# tiempo de simulacion: 49.0 dias
# tiempo de simulacion: 49.1 dias
# tiempo de simulacion: 49.2 dias
# tiempo de simulacion: 49.3 dias
# tiempo de simulacion: 49.4 dias
# tiempo de simulacion: 49.5 dias
# tiempo de simulacion: 49.6 dias
# tiempo de simulacion: 49.7 dias
# tiempo de simulacion: 49.8 dias
# tiempo de simulacion: 49.9 dias
# tiempo de simulacion: 50.0 dias
# tiempo de simulacion: 50.1 dias
# tiempo de simulacion: 50.2 dias
# tiempo de simulacion: 50.3 dias
# tiempo de simulacion: 50.4 dias
# tiempo de simulacion: 50.5 dias
# tiempo de simulacion: 50.6 dias
# tiempo de simulacion: 50.7 dias
# tiempo de simulacion: 50.8 dias
#
# Tiempo de Ejecución: 4.3789472579956055 [Segundos] 	 0.07298245429992675 [Minutos]
#
# |------------------------------------------------------------------------------|
# |-------------------------- FIN DE LA SIMULACIÓN xdxd -------------------------|
# |------------------------------------------------------------------------------|
